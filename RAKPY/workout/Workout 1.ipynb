# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats as s

# %%
df=pd.read_csv('USA_Housing.csv')
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df2=pd.read_csv('Housing.csv')
df2.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df3=pd.concat([df,df2],axis=1)

# %%
df3.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address       price    area  \
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...  13300000.0  7420.0
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...  12250000.0  8960.0
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...  12250000.0  9960.0
# 3                          USS Barnett\nFPO AP 44820  12215000.0  7500.0
# 4                         USNS Raymond\nFPO AE 09386  11410000.0  7420.0
#
#    bedrooms  bathrooms  stories mainroad guestroom basement hotwaterheating  \
# 0       4.0        2.0      3.0      yes        no       no              no
# 1       4.0        4.0      4.0      yes        no       no              no
# 2       3.0        2.0      2.0      yes        no      yes              no
# 3       4.0        2.0      2.0      yes        no      yes              no
# 4       4.0        1.0      2.0      yes       yes      yes              no
#
#   airconditioning  parking prefarea furnishingstatus
# 0             yes      2.0      yes        furnished
# 1             yes      3.0       no        furnished
# 2              no      2.0      yes   semi-furnished
# 3             yes      3.0      yes        furnished
# 4             yes      2.0       no        furnished

# %%
df3.isnull().sum()
# Out:
# Avg. Area Income                   0
# Avg. Area House Age                0
# Avg. Area Number of Rooms          0
# Avg. Area Number of Bedrooms       0
# Area Population                    0
# Price                              0
# Address                            0
# price                           4455
# area                            4455
# bedrooms                        4455
# bathrooms                       4455
# stories                         4455
# mainroad                        4455
# guestroom                       4455
# basement                        4455
# hotwaterheating                 4455
# airconditioning                 4455
# parking                         4455
# prefarea                        4455
# furnishingstatus                4455
# dtype: int64

# %%
df3['price'].mean()
# Out:
# 4766729.247706422

# %%
df3['Price']=df3['Price']/1000000

# %%
df3.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population     Price  \
# 0                          4.09     23086.800503  1.059034
# 1                          3.09     40173.072174  1.505891
# 2                          5.13     36882.159400  1.058988
# 3                          3.26     34310.242831  1.260617
# 4                          4.23     26354.109472  0.630943
#
#                                              Address       price    area  \
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...  13300000.0  7420.0
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...  12250000.0  8960.0
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...  12250000.0  9960.0
# 3                          USS Barnett\nFPO AP 44820  12215000.0  7500.0
# 4                         USNS Raymond\nFPO AE 09386  11410000.0  7420.0
#
#    bedrooms  bathrooms  stories mainroad guestroom basement hotwaterheating  \
# 0       4.0        2.0      3.0      yes        no       no              no
# 1       4.0        4.0      4.0      yes        no       no              no
# 2       3.0        2.0      2.0      yes        no      yes              no
# 3       4.0        2.0      2.0      yes        no      yes              no
# 4       4.0        1.0      2.0      yes       yes      yes              no
#
#   airconditioning  parking prefarea furnishingstatus
# 0             yes      2.0      yes        furnished
# 1             yes      3.0       no        furnished
# 2              no      2.0      yes   semi-furnished
# 3             yes      3.0      yes        furnished
# 4             yes      2.0       no        furnished

# %%
col=list(df3.columns[df3.isnull().sum()>0])

# %%
for i in col:
    if df3[i].dtypes=='float64':
        df3[i].fillna(value=df3[i].sum()/len(df3[i]),inplace=True)
    elif df3[i].dtypes=='object':
        df3[i].fillna(method='ffill',inplace=True)

# %%
df3.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# price                           0
# area                            0
# bedrooms                        0
# bathrooms                       0
# stories                         0
# mainroad                        0
# guestroom                       0
# basement                        0
# hotwaterheating                 0
# airconditioning                 0
# parking                         0
# prefarea                        0
# furnishingstatus                0
# dtype: int64

# %%
df3.shape
# Out:
# (5000, 20)

# %%
a=set(df3['furnishingstatus'])

# %%
for j in a:
    df3[j]=df3['furnishingstatus'].apply(lambda x:1 if x==j else 0)

# %%
df3.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population     Price  \
# 0                          4.09     23086.800503  1.059034
# 1                          3.09     40173.072174  1.505891
# 2                          5.13     36882.159400  1.058988
# 3                          3.26     34310.242831  1.260617
# 4                          4.23     26354.109472  0.630943
#
#                                              Address       price    area  \
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...  13300000.0  7420.0
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...  12250000.0  8960.0
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...  12250000.0  9960.0
# 3                          USS Barnett\nFPO AP 44820  12215000.0  7500.0
# 4                         USNS Raymond\nFPO AE 09386  11410000.0  7420.0
#
#    bedrooms  ...  guestroom  basement hotwaterheating airconditioning parking  \
# 0       4.0  ...         no        no              no             yes     2.0
# 1       4.0  ...         no        no              no             yes     3.0
# 2       3.0  ...         no       yes              no              no     2.0
# 3       4.0  ...         no       yes              no             yes     3.0
# 4       4.0  ...        yes       yes              no             yes     2.0
#
#   prefarea furnishingstatus  furnished unfurnished semi-furnished
# 0      yes        furnished          1           0              0
# 1       no        furnished          1           0              0
# 2      yes   semi-furnished          0           0              1
# 3      yes        furnished          1           0              0
# 4       no        furnished          1           0              0
#
# [5 rows x 23 columns]

# %%
MR_house=df3[df3['mainroad']=='yes']

# %%
MR_house.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population     Price  \
# 0                          4.09     23086.800503  1.059034
# 1                          3.09     40173.072174  1.505891
# 2                          5.13     36882.159400  1.058988
# 3                          3.26     34310.242831  1.260617
# 4                          4.23     26354.109472  0.630943
#
#                                              Address       price    area  \
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...  13300000.0  7420.0
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...  12250000.0  8960.0
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...  12250000.0  9960.0
# 3                          USS Barnett\nFPO AP 44820  12215000.0  7500.0
# 4                         USNS Raymond\nFPO AE 09386  11410000.0  7420.0
#
#    bedrooms  ...  guestroom  basement hotwaterheating airconditioning parking  \
# 0       4.0  ...         no        no              no             yes     2.0
# 1       4.0  ...         no        no              no             yes     3.0
# 2       3.0  ...         no       yes              no              no     2.0
# 3       4.0  ...         no       yes              no             yes     3.0
# 4       4.0  ...        yes       yes              no             yes     2.0
#
#   prefarea furnishingstatus  furnished unfurnished semi-furnished
# 0      yes        furnished          1           0              0
# 1       no        furnished          1           0              0
# 2      yes   semi-furnished          0           0              1
# 3      yes        furnished          1           0              0
# 4       no        furnished          1           0              0
#
# [5 rows x 23 columns]

# %%
set(MR_house['mainroad'])
# Out:
# {'yes'}

# %%
fig=plt.figure()
sns.heatmap(df3.corr(),annot=True,ax=fig.add_axes([0,0,2,2]))

# %%
# sns.barplot(df3['Avg. Area House Age'],df3['price'])

# %%
sns.distplot(df3['Area Population'],vertical=False)

# %%
sns.distplot(df3['Avg. Area Income'], rug=True, rug_kws={"color": "g"},
                       kde_kws={"color": "black", "lw": 3, "label": "KDE"},
                       hist_kws={"histtype": "step", "linewidth": 3,
                                 "alpha": 1, "color": "g"})
